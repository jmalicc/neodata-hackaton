# %%
#!/usr/bin/env python3

import os
import numpy as np
import matplotlib.image as mpimg
import re

foreground_threshold = 0.25 # percentage of pixels > 1 required to assign a foreground label to a patch

# assign a label to a patch
def patch_to_label(patch):
    df = np.mean(patch)
    if df > foreground_threshold:
        return 1
    else:
        return 0


def mask_to_submission_strings(image_filename):
    """Reads a single image and outputs the strings that should go into the submission file"""
    img_number = int(re.search(r"\d+", image_filename).group(0))
    im = mpimg.imread(image_filename)
    patch_size = 16
    for j in range(0, im.shape[1], patch_size):
        for i in range(0, im.shape[0], patch_size):
            patch = im[i:i + patch_size, j:j + patch_size]
            label = patch_to_label(patch)
            yield("{:03d}_{}_{},{}".format(img_number, j, i, label))


def masks_to_submission(submission_filename, *image_filenames):
    """Converts images into a submission file"""
    with open(submission_filename, 'w') as f:
        f.write('id,prediction\n')
        for fn in image_filenames[0:]:
            f.writelines('{}\n'.format(s) for s in mask_to_submission_strings(fn))


if __name__ == '__main__':
    submission_filename = 'dummy_submission3.csv'
    image_filenames = []
    for i in range(1, 51):
        image_filename = 'test\predicted_masks_test_v2/test_' + str(i) + '.png'
        print(image_filename)
        image_filenames.append(image_filename)
    masks_to_submission(submission_filename, *image_filenames)
# Out:
# test\predicted_masks_test_v2/test_1.png
# test\predicted_masks_test_v2/test_2.png
# test\predicted_masks_test_v2/test_3.png
# test\predicted_masks_test_v2/test_4.png
# test\predicted_masks_test_v2/test_5.png
# test\predicted_masks_test_v2/test_6.png
# test\predicted_masks_test_v2/test_7.png
# test\predicted_masks_test_v2/test_8.png
# test\predicted_masks_test_v2/test_9.png
# test\predicted_masks_test_v2/test_10.png
# test\predicted_masks_test_v2/test_11.png
# test\predicted_masks_test_v2/test_12.png
# test\predicted_masks_test_v2/test_13.png
# test\predicted_masks_test_v2/test_14.png
# test\predicted_masks_test_v2/test_15.png
# test\predicted_masks_test_v2/test_16.png
# test\predicted_masks_test_v2/test_17.png
# test\predicted_masks_test_v2/test_18.png
# test\predicted_masks_test_v2/test_19.png
# test\predicted_masks_test_v2/test_20.png
# test\predicted_masks_test_v2/test_21.png
# test\predicted_masks_test_v2/test_22.png
# test\predicted_masks_test_v2/test_23.png
# test\predicted_masks_test_v2/test_24.png
# test\predicted_masks_test_v2/test_25.png
# test\predicted_masks_test_v2/test_26.png
# test\predicted_masks_test_v2/test_27.png
# test\predicted_masks_test_v2/test_28.png
# test\predicted_masks_test_v2/test_29.png
# test\predicted_masks_test_v2/test_30.png
# test\predicted_masks_test_v2/test_31.png
# test\predicted_masks_test_v2/test_32.png
# test\predicted_masks_test_v2/test_33.png
# test\predicted_masks_test_v2/test_34.png
# test\predicted_masks_test_v2/test_35.png
# test\predicted_masks_test_v2/test_36.png
# test\predicted_masks_test_v2/test_37.png
# test\predicted_masks_test_v2/test_38.png
# test\predicted_masks_test_v2/test_39.png
# test\predicted_masks_test_v2/test_40.png
# test\predicted_masks_test_v2/test_41.png
# test\predicted_masks_test_v2/test_42.png
# test\predicted_masks_test_v2/test_43.png
# test\predicted_masks_test_v2/test_44.png
# test\predicted_masks_test_v2/test_45.png
# test\predicted_masks_test_v2/test_46.png
# test\predicted_masks_test_v2/test_47.png
# test\predicted_masks_test_v2/test_48.png
# test\predicted_masks_test_v2/test_49.png
# test\predicted_masks_test_v2/test_50.png
